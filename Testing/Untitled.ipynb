# %%
import sys
sys.path.append('/home/gabriel/Projects/CybORG-Sims/CybORG')
from CybORG import CybORG
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('/home/gabriel/Projects/CybORG-Sims/CybORG')
# ----> 3 from CybORG import CybORG
#
# File ~/Projects/CybORG-Sims/CybORG/CybORG/__init__.py:4
#       1 import inspect
#       2 # allows import of CybORG class as:
#       3 # from CybORG import CybORG
# ----> 4 from CybORG.env import CybORG
#       6 path = str(inspect.getfile(CybORG))
#       7 path = path[:-7] + '/version.txt'
#
# File ~/Projects/CybORG-Sims/CybORG/CybORG/env.py:5
#       2 import warnings
#       3 from typing import Any, Union
# ----> 5 import gym
#       6 from gym.utils import seeding
#       8 from CybORG.Shared import Observation, Results, CybORGLogger
#
# ModuleNotFoundError: No module named 'gym'
